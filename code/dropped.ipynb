# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
characters_data = pd.read_csv('/content/drive/MyDrive/characters_ani.csv')
anime_data = pd.read_csv('/content/drive/MyDrive/anime.csv')

# %%
characters_data.head()
# Out:
#    Unnamed: 0   ID            Name  \
# 0           0    0               L
# 1          98   98  Kakashi HATAKE
# 2         348  348    Light YAGAMI
# 3         279  279  Naruto UZUMAKI
# 4         103  103    Edward ELRIC
#
#                                           Alias Gender Hair Color  Love Rank  \
# 0                                       Ryuzaki   Male      Black        1.0
# 1  Copy Ninja Kakashi, Kakashi of the Sharingan   Male       Grey        2.0
# 2                                          Kira   Male      Brown        4.0
# 3                                       Unknown   Male     Blonde        6.0
# 4                           Fullmetal Alchemist   Male     Blonde        3.0
#
#    Hate Rank Eye color           Birthday Blood Type  \
# 0       48.0     Black   October 31, 1979    Unknown
# 1      320.0     Black       September 15          O
# 2        9.0     Brown  February 28, 1986          A
# 3       20.0      Blue         October 10          B
# ...

# %%
anime_data.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# ...

# %%
characters_dropped = characters_data[['ID', 'Gender', 'Hair Color', 'Tags', 'MAL_ID']]
characters_desc = characters_data[['ID', 'Description', 'MAL_ID']]

# %%
anime_dropped = anime_data[['MAL_ID', 'Genres', 'Type', 'Aired', 'Source']]

# %%
df_INNER_JOIN = pd.merge(characters_dropped, anime_dropped, left_on='MAL_ID', right_on='MAL_ID', how='inner')
df_INNER_JOIN.head()
# Out:
#     ID  Gender Hair Color                                               Tags  \
# 0    0    Male      Black  Analytical, Barefoot, Detectives, Eye Bags, Sw...
# 1  348    Male      Brown  Analytical, Big Ego, Charismatic, God Complex,...
# 2  155    Male      Black  Agents of the Afterlife, Anti-Gravity Hair, Im...
# 3  238  Female     Blonde                       Hyperactive, Idols, Pigtails
# 4  180    Male      White                  Analytical, Detectives, Teenagers
#
#    MAL_ID                                             Genres Type  \
# 0  1535.0  Mystery, Police, Psychological, Supernatural, ...   TV
# 1  1535.0  Mystery, Police, Psychological, Supernatural, ...   TV
# 2  1535.0  Mystery, Police, Psychological, Supernatural, ...   TV
# 3  1535.0  Mystery, Police, Psychological, Supernatural, ...   TV
# 4  1535.0  Mystery, Police, Psychological, Supernatural, ...   TV
#
#                          Aired Source
# 0  Oct 4, 2006 to Jun 27, 2007  Manga
# ...
